# %% [markdown]
# # Simple Imputation

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import Imputer # Imputer object from Sklearn

# read in data
df = pd.read_csv('airquality.csv')
# clean up data a bit
df.drop('Unnamed: 0', 1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 6 columns):
# Ozone      116 non-null float64
# Solar.R    146 non-null float64
# Wind       153 non-null float64
# Temp       153 non-null int64
# Month      153 non-null int64
# Day        153 non-null int64
# dtypes: float64(3), int64(3)
# memory usage: 7.2 KB

# %% [markdown]
# # Make imputer object
#
# look into the "Imputer" documentation to find all of the imputation methods that this object can handle

# %%
# create imputer object
imp = Imputer(missing_values = 'NaN', strategy = 'mean')
# imputer for Ozone
df['Ozone'] = imp.fit_transform(df[['Ozone']])
# impute for Solar.R
df['Solar.R'] = imp.fit_transform(df[['Solar.R']])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 6 columns):
# Ozone      153 non-null float64
# Solar.R    153 non-null float64
# Wind       153 non-null float64
# Temp       153 non-null int64
# Month      153 non-null int64
# Day        153 non-null int64
# dtypes: float64(3), int64(3)
# memory usage: 7.2 KB

# %% [markdown]
# # Feature Importances

# %%
from sklearn.ensemble import RandomForestRegressor

df['RANDOM'] = np.random.rand(len(df))*100

y = df['Ozone']
x = df.drop('Ozone', axis = 1)
df
# Out:
#          Ozone     Solar.R  Wind  Temp  Month  Day     RANDOM
# 0     41.00000  190.000000   7.4    67      5    1  99.518548
# 1     36.00000  118.000000   8.0    72      5    2  10.096782
# 2     12.00000  149.000000  12.6    74      5    3  55.418138
# 3     18.00000  313.000000  11.5    62      5    4  78.716309
# 4     42.12931  185.931507  14.3    56      5    5  19.693314
# 5     28.00000  185.931507  14.9    66      5    6  91.285385
# 6     23.00000  299.000000   8.6    65      5    7  81.740462
# 7     19.00000   99.000000  13.8    59      5    8  79.904547
# 8      8.00000   19.000000  20.1    61      5    9  10.320575
# 9     42.12931  194.000000   8.6    69      5   10  82.571569
# 10     7.00000  185.931507   6.9    74      5   11  57.115826
# 11    16.00000  256.000000   9.7    69      5   12  47.442511
# 12    11.00000  290.000000   9.2    66      5   13  76.083578
# 13    14.00000  274.000000  10.9    68      5   14  99.685351
# 14    18.00000   65.000000  13.2    58      5   15  31.712046
# 15    14.00000  334.000000  11.5    64      5   16   6.935645
# 16    34.00000  307.000000  12.0    66      5   17   9.915609
# 17     6.00000   78.000000  18.4    57      5   18  43.259626
# 18    30.00000  322.000000  11.5    68      5   19  15.203433
# 19    11.00000   44.000000   9.7    62      5   20  80.267615
# 20     1.00000    8.000000   9.7    59      5   21  95.767831
# 21    11.00000  320.000000  16.6    73      5   22  28.948275
# 22     4.00000   25.000000   9.7    61      5   23  56.795864
# 23    32.00000   92.000000  12.0    61      5   24  61.509640
# 24    42.12931   66.000000  16.6    57      5   25  85.944585
# 25    42.12931  266.000000  14.9    58      5   26  99.116991
# 26    42.12931  185.931507   8.0    57      5   27  29.707640
# 27    23.00000   13.000000  12.0    67      5   28  28.079825
# 28    45.00000  252.000000  14.9    81      5   29  49.035654
# 29   115.00000  223.000000   5.7    79      5   30  13.882815
# ..         ...         ...   ...   ...    ...  ...        ...
# 123   96.00000  167.000000   6.9    91      9    1  67.099083
# 124   78.00000  197.000000   5.1    92      9    2  17.208050
# 125   73.00000  183.000000   2.8    93      9    3   9.176876
# 126   91.00000  189.000000   4.6    93      9    4  22.917410
# 127   47.00000   95.000000   7.4    87      9    5  55.535633
# 128   32.00000   92.000000  15.5    84      9    6  74.575043
# 129   20.00000  252.000000  10.9    80      9    7  86.119119
# 130   23.00000  220.000000  10.3    78      9    8  67.056981
# 131   21.00000  230.000000  10.9    75      9    9  63.249763
# 132   24.00000  259.000000   9.7    73      9   10  44.099173
# 133   44.00000  236.000000  14.9    81      9   11  39.023927
# 134   21.00000  259.000000  15.5    76      9   12  30.562592
# 135   28.00000  238.000000   6.3    77      9   13  86.821208
# 136    9.00000   24.000000  10.9    71      9   14  59.458084
# 137   13.00000  112.000000  11.5    71      9   15  35.885863
# 138   46.00000  237.000000   6.9    78      9   16  58.357731
# 139   18.00000  224.000000  13.8    67      9   17   6.008945
# 140   13.00000   27.000000  10.3    76      9   18  57.380889
# 141   24.00000  238.000000  10.3    68      9   19   6.973556
# 142   16.00000  201.000000   8.0    82      9   20   9.853518
# 143   13.00000  238.000000  12.6    64      9   21  19.061644
# 144   23.00000   14.000000   9.2    71      9   22   7.133435
# 145   36.00000  139.000000  10.3    81      9   23  91.335485
# 146    7.00000   49.000000  10.3    69      9   24  49.032860
# 147   14.00000   20.000000  16.6    63      9   25  59.342897
# 148   30.00000  193.000000   6.9    70      9   26  69.387941
# 149   42.12931  145.000000  13.2    77      9   27  22.998325
# 150   14.00000  191.000000  14.3    75      9   28  79.412386
# 151   18.00000  131.000000   8.0    76      9   29  19.776913
# 152   20.00000  223.000000  11.5    68      9   30  96.336890
#
# [153 rows x 7 columns]

# %%
# model
forest = RandomForestRegressor(n_estimators = 100)

# train
forest.fit(x, y)

# feature importances
pd.DataFrame({'Importance': forest.feature_importances_}, 
                   index = x.columns).sort_values('Importance', 
                                                  ascending = False)
# Out:
#          Importance
# Temp       0.459255
# Wind       0.289587
# Solar.R    0.091045
# Day        0.076959
# RANDOM     0.055950
# Month      0.027204
